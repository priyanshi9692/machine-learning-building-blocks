# %% [markdown]
# # Data Exploration and Data Visualization

# %% [markdown]
# ## Introduction to Pandas 🐼 and NumPy
#
# ### Pandas
#
# Pandas is a very popular library for working with datasets. DataFrames are at the center of pandas. A DataFrame is structured like a table or spreadsheet. The rows and the columns both have indexes, and you can perform operations on rows or columns separately.
# A Pandas DataFrame can be **easily changed and manipulated**. Pandas has helpful functions for **handling missing data, performing operations on columns and rows, and transforming data**. If that wasn’t enough, **a lot of SQL functions have counterparts in pandas, such as join, merge, filter by, and group by**. With all of these powerful tools, it should come as no surprise that pandas is very popular among data scientists.
#
# ### NumPy
#
# NumPy is an open-source Python library that facilitates efficient numerical operations on large quantities of data. There are a few functions that exist in NumPy that we use on pandas DataFrames. For us, the most important part about NumPy is that pandas is built on top of it. So, NumPy is a dependency of Pandas.
#
# ### Data Visualization libraries
#
# 1. Seaborn: https://seaborn.pydata.org/generated/seaborn.catplot.html
# 2. Matplotlib: https://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot#plot-column-values-as-a-bar-plot

# %% [markdown]
# # Lab-1 (Data Exploration and Feature Engineering)

# %% [markdown]
# ## RMS Titanic 🛥️
#
# ![RMS%20titanic.jpeg](attachment:RMS%20titanic.jpeg)
#
#
# The RMS Titanic was a British passenger liner that sank in the North Atlantic Ocean in the early morning hours of 15 April 1912, after it collided with an iceberg during its maiden voyage from Southampton to New York City. There were an estimated 2,224 passengers and crew aboard the ship, and more than 1,500 died, making it one of the deadliest commercial peacetime maritime disasters in modern history. The RMS Titanic was the largest ship afloat at the time it entered service and was the second of three Olympic-class ocean liners operated by the White Star Line. The Titanic was built by the Harland and Wolff shipyard in Belfast. Thomas Andrews, her architect, died in the disaster.
#
# ## Data Exploration
#
# As part of this activity, we will try to understand features of Titanic dataset, dataset is already available for us (I downloaded it from the Kaggle: https://www.kaggle.com/competitions/titanic/data). We will bring this dataset into this Jupyter notebook (https://jupyter.org/) and will do some data analysis on it.

# %% [markdown]
# ### Import libraries
# 1. For linear algebra we would need NumPy library
# 2. Data Manipulation and preprocessing we would need Pandas library
# 3. Data Visualization can be done by seaborn, matplotlib libraries

# %%
# Import libraries

# linear algebra
import numpy as np 

# data processing
import pandas as pd 

# !pip install seaborn
# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style
# Out:
# zsh:1: /opt/homebrew/bin/pip: bad interpreter: /opt/homebrew/opt/python@3.10/bin/python3.10: no such file or directory
# ...

# %% [markdown]
# ### Getting dataset
#
# Dataset is in csv form, and pandas provides capabilities to convert csv files into dataframes
#
# `dataframe = pd.read_csv("file1.csv")`

# %%
"""
Get train and test dataset

write code to bring in train csv file in pandas dataframe (~ 1 line of code)
train_df = #code
write code to bring in test csv file in pandas dataframe (~ 1 line of code)
test_df = #code
"""

# YOUR CODE STARTS HERE
train_df = None
test_df = None
# YOUR CODE ENDS HERE

# %% [markdown]
# ### View the dataframe

# %%
# train_df
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# test_df
test_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ### Columns in Dataframe
#
# Dataframe.columns returns column labels of the DataFrame.

# %%
"""
Get column labels of the train dataframe using columns (~ 1 line of code)
dataframe name is train_df
"""

# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Summary of Dataframe
#
# Pandas provides info() function that can help us to get a concise summary of the dataframe. Let's use this to get a quick overview of Titanic dataset

# %%
"""
Get info of the train dataframe using info() function (~ 1 line of code)
"""

# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Short description of the features
#
# `survival:    Survival
#  PassengerId: Unique Id of a passenger.
#  pclass:    Ticket class
#  sex:    Sex
#  Age:    Age in years
#  sibsp:    # of siblings / spouses aboard the Titanic
#  parch:    # of parents / children aboard the Titanic
#  ticket:    Ticket number
#  fare:    Passenger fare
#  cabin:    Cabin number
#  embarked:    Port of Embarkation`

# %% [markdown]
# ### Description of Dataframe
#
# The describe() method returns description of the data in the DataFrame. If the DataFrame contains numerical data, the description contains these information for each column: count - The number of not-empty values. mean - The average (mean) value. std - The standard deviation

# %%
"""
Get Description of the training dataframe using describe() method (~ 1 line of code)
"""

# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Head and Tail methods
#
#
# The head() function in pandas displays the top rows of a DataFrame, while the tail() function shows the bottom rows. Both functions are used to get a quick overview of the data's structure and contents, making them essential tools for data exploration and analysis in Python.

# %%
"""
Let's display top 10 rows of a Dataframe using head() method (~ 1 line of code)
"""


# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
"""
Let's display bottom 5 rows of a Dataframe using tail() method (~ 1 line of code)
"""


# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# From the table above, we can understand few things,
#
# 1. We need to convert a lot of features into numeric ones later on, so that the machine learning algorithms can process them.
# 2. Furthermore, we can see that the features have widely different ranges, that we will need to convert into roughly the same scale. (essentially Normalization)
# 3. We can also spot some more features, that contain missing values (NaN = not a number), that we need to process either by dropping NaN value or replacing it with a relevant number)
#
# So, let's first check columns that have null values

# %% [markdown]
# ### Check is the dataframe columns have null value or not
#
# Pandas isnull() method detects missing values in the given column

# %%
"""
Use isnull() function to detect missing values in the given column (~ 1 line of code)
"""


# YOUR CODE STARTS HERE

# YOUR CODE ENDS HERE
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %% [markdown]
# #### Let's try to find out how many null/None values are there in each column
#
# Let's take a simple example and then we will try to use the same manipulation for our dataframe

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'A': [1, 2, None, 4, 5],
    'B': [None, 2, 3, None, 5],
    'C': [1, 2, 3, 4, 5]
}

df = pd.DataFrame(data)

# Count null values in each column
null_counts = df.isnull().sum()

# Display the results
print(null_counts)
# Out:
# A    1
# B    2
# C    0
# dtype: int64

# %% [markdown]
# Try to write the same logic to get count of null values each column

# %%
"""
Get null value count for each column and sort them in descending order (~ 1 line of code)
Hint: for sorting use sort_values(ascending = ...)
"""


# YOUR CODE STARTS HERE
null_count = None
# YOUR CODE ENDS HERE

# %%
null_count
# Out:
# Cabin          687
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# dtype: int64

# %% [markdown]
# The above details helps us to get insight,the **Embarked** feature has only 2 missing values, which can easily be filled.
# Whereas the **Age** feature has 177 missing values and **Cabin** feature needs further investigation.

# %% [markdown]
# At a first glance of this dataset, it seems that all the features except PassengerId, Ticket, and Name would contribute to the survival of a passenger.

# %% [markdown]
# ## Plots
#
# ### Age and Sex
#
# Let us plot a some charts to get more insights of the dataset, and understand what are the features impacting a person's survival in Titanic

# %%
# Creating labels for figures
survived = 'survived'
not_survived = 'not survived'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 8))

# Extract exclusive rows where Sex is Female and Male
women = train_df[train_df['Sex']=='female']
men = train_df[train_df['Sex']=='male']

# Plot histplot for the Survived and Not survives age groups for Female
ax = sns.histplot(women[women['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False)
ax = sns.histplot(women[women['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False)
ax.legend()
ax.set_title('Female')


# Plot histplot for the Survived and Not survives age groups for Female
ax = sns.histplot(men[men['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.histplot(men[men['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)
ax.legend()
_ = ax.set_title('Male')

# %% [markdown]
# The data from the Titanic reveals an interesting pattern:
#
# 1. Men between the ages of 18 and 30 had the best chances of survival though the same age group has more number of men who did not survive. This age group shows the highest probability of making it through the disaster. However, this trend is not limited to men; it also applies to women, especially those between the ages of 14 and 40.
#
# 2. For men, there was a significant drop in survival probability for those aged between 5 and 18. Surprisingly, this dip is not observed among women. Additionally, infants had a slightly better chance of survival.
#
# 3. Because specific age ranges seem to correlate with increased odds of survival, and to ensure that all the features we analyze are on a similar scale, we will create group of passengers based on the age categories later in our analysis.

# %% [markdown]
# ### Embarked, Pclass and Sex
#
# FacetGrid chart: This class maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset. The plots it produces are often called “lattice”, “trellis”, or “small-multiple” graphics.
#
# Seaborn's pointplot function to visualize the relationships between the 'Pclass' (passenger class), 'Survived' (survival status), and 'Sex' (gender) variables. It likely uses different colors to distinguish between categories within the 'Sex' variable. The FacetGrid organizes these plots into a grid, which can be useful for comparing different subsets of the data

# %%
FacetGrid = sns.FacetGrid(train_df, row='Embarked', height=4, aspect=1.8)
FacetGrid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', palette='dark:#1f77b4', order=None, hue_order=None )
FacetGrid.add_legend()

# %% [markdown]
# Embarked seems to be correlated with survival, depending on the gender.
#
# Women on port Q had a higher chances of survival. Men have a high survival probability if they were on port S and C, but a low probability if they are on port Q.
#
# Pclass also seems to be correlated with survival. We will generate another plot of it below.

# %% [markdown]
# ### PClass: SNS Barplot
#
# A bar plot represents an aggregate or statistical estimate for a numeric variable with the height of each rectangle and indicates the uncertainty around that estimate using an error bar. Bar plots include 0 in the axis range, and they are a good choice when 0 is a meaningful value for the variable to take.

# %%
sns.barplot(train_df, x='Pclass', y='Survived', hue = 'Pclass', legend=False)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# Above barplot shows, that Pclass is contributing to a passanger's chances of survival, especially if this passenger is in Pclass 1. Let's explore more about this Pclass plot.

# %%
grid = sns.FacetGrid(train_df, col='Survived', row='Pclass', height=3.2, aspect=1.8)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend();

# %% [markdown]
# The plots above also gives us insights that pclass 1 passangers have high probability to service and pclass 3 passengers are more prone to die.

# %% [markdown]
# ### SibSp and Parch
#
# SibSp and Parch would make more sense as a combined feature, that shows the total number of relatives, a person has on the Titanic. Let's create a plot create that can help us to see how many passengers were not alone.

# %%
data = [train_df, test_df]
for dataset in data:
    dataset['relatives'] = dataset['SibSp'] + dataset['Parch']
    dataset.loc[dataset['relatives'] > 0, 'not_alone'] = 0
    dataset.loc[dataset['relatives'] == 0, 'not_alone'] = 1
    dataset['not_alone'] = dataset['not_alone'].astype(int)
train_df['not_alone'].value_counts()
# Out:
# 1    537
# 0    354
# Name: not_alone, dtype: int64

# %% [markdown]
# ### Plot pivot table
#
# From the pivot table below, we see that females in first class had a survival rate of about 96.8%, meaning the majority of them survived.
#
# Males in third class had the lowest survival rate at about 13.54%, meaning the majority of them did not survive.

# %%
train_df.pivot_table('Survived', index='Sex', columns='Pclass')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
train_df.pivot_table('Survived', index='Sex', columns='Pclass').plot()
# Out:
# <AxesSubplot:xlabel='Sex'>

# %% [markdown]
# # References :)
#
# 1. https://www.codecademy.com/article/introduction-to-numpy-and-pandas
# 2. https://www.w3schools.com/python/pandas/pandas_intro.asp
# 3. https://towardsdatascience.com/pandas-and-python-tips-and-tricks-for-data-science-and-data-analysis-1b1e05b7d93a
